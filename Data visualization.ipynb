# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.datasets.samples_generator import make_blobs
from sklearn.decomposition import PCA

# %%
for file in os.listdir('trajectories/'):
    df = pd.read_csv(file)
    df_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0de9b58ce4d8> in <module>()
#       1 for file in os.listdir('trajectories/'):
# ----> 2     df = pd.read_csv(file)
#       3     df_list.append(df)
#
# NameError: name 'pd' is not defined

# %%
dataframe = np.genfromtxt('trajectories/Fish12 NE2 C200_clean.csv', delimiter=",")
scaler = StandardScaler()
dataframe = scaler.fit_transform(dataframe)
count = 999

# %%
dataframe.size
# Out:
# 53946

# %%
plt.plot(dataframe[:count,0], dataframe[:count,1])

# %%
dataframe2 = scaler.fit_transform(np.genfromtxt("trajectories/Fish5 NE2 C30_clean.csv", delimiter=","))
plt.plot(dataframe2[:,0], dataframe2[:,1])

# %%
plt.plot(dataframe2[1500:3000,0], dataframe2[1500:3000,1])
h = np.reshape(dataframe,(-1,))
b = np.reshape(dataframe2, (-1,))

# %%
p = PCA(n_components=1)
p.fit(dataframe)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
dataframe_pca = p.transform(dataframe)
pca2 = PCA(n_components=1)

dataframe2_pca = p.fit_transform(dataframe2)

# %%
plt.plot(dataframe_pca)

# %%
plt.plot(pca2.transform(dataframe2))

# %%
plt.plot(p.transform(scaler.fit_transform(np.genfromtxt("trajectories/Fish5 NE1 C200_clean.csv", delimiter=","))))

# %%
test = np.stack((h[:500],b[:500]))
y = np.c_[(1,0)].T

# %%
test.shape
# Out:
# (2, 500)

# %%
clf = SVC(kernel='rbf', probability=False,verbose=False)

# %%
clf.fit(test,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
clf.predict(scaler.fit_transform((np.genfromtxt('trajectories/Fish5 NE1 C200_clean.csv', delimiter=",")).reshape((1,-1)))[:,:500])
# Out:
# array([1])

# %%
scaler.fit_transform(np.genfromtxt('trajectories/Fish8 NE2 C30_clean.csv', delimiter=","))
# Out:
# array([[-1.32676636, -0.44455553],
#        [-1.20027938, -0.27398928],
#        [-1.04095719, -0.10915634],
#        ...,
#        [-1.21427004, -0.31519751],
#        [-1.24710526, -0.17974784],
#        [-1.23768298, -0.20339778]])

# %%
(np.genfromtxt('trajectories/Fish8 NE1 C200_clean.csv', delimiter=",")).reshape((1,-1))[:,:500].shape
# Out:
# (1, 500)
